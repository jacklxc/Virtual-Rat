# %%
import numpy as npp
import minpy.numpy as np
import cPickle
import matplotlib.pyplot as plt
import minpy
minpy.set_global_policy('only_numpy')

from SimplePolicyNetwork import SimplePolicyNetwork
from SimpleRLPolicyGradientSolver import SimpleRLPolicyGradientSolver
from simpleBox import simpleBox
from SimRat import SimRat
from dataProcessFunctions import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
box = simpleBox(mode="alternative",length=1000,block_size=30,random_range=0,trial_per_episode=5, repeat = True)
val_X, val_y = box.X,box.y
all_solvers = []
all_rats = []
#loaded_params = load_weights("good_weights/good_weights3.pkl")
for i in range(2):
    solvers = {}
    rats = {}
    p2a_ratio = i
    for j in range(5):
        ratname = 'VirtualRat'+str(p2a_ratio)+"-"+str(j)
        print ratname
        model = SimplePolicyNetwork(hidden_dim=10,reg=0, noise_factor = 0)
        rat = SimRat(model)
        box = simpleBox(mode="switch_ratio",length=10000,block_size=30,random_range=0,
                        trial_per_episode=50, repeat = True, reward_ratio = 1, p2a = p2a_ratio, correction = True)
        solver = SimpleRLPolicyGradientSolver(model, box,
                                            update_rule='adam',
                                            optim_config={
                                                'learning_rate': 1e-2,
                                                'decay_rate': 1
                                            },
                                            init_rule='xavier',
                                            num_episodes=301,
                                            verbose=False,
                                            supervised = True,
                                            stop = False,
                                            print_every=50)
        
        solver.init()
        #solver.load_params(loaded_params)
        solver.set_temperature(5.0)
        solver.train()

        rats[ratname] = rat

        probs = rat.predict(val_X,val_y)
        trial_window = 3
        
        draw_3d(rat.p2a_prob, rat.a2p_prob, trial_window = 3)
        draw_3d_new(rat.p2a_left_prob, rat.p2a_right_prob, rat.a2p_left_prob, rat.a2p_right_prob, trial_window = 3)

        solvers[ratname] = solver
        rat.addHistory(box.output_history())
        rat.computeLearningCurve()

    trial_window = 3
    p2a_mean, a2p_mean, p2a_left_mean, a2p_left_mean, p2a_right_mean, a2p_right_mean = meanPerformance(rats, trial_window = 3)
    draw_3d(p2a_mean, a2p_mean, trial_window = 3)
    draw_3d_new(rat.p2a_left_prob, rat.p2a_right_prob, rat.a2p_left_prob, rat.a2p_right_prob, trial_window = 3)
    pro_mean, anti_mean = meanLearningCurve(rats)
    learningCurve(pro_mean,anti_mean, rats)
    all_solvers.append(solvers)
    all_rats.append(rats)
# Out:
# VirtualRat0-0
# Episode 50 complete (0.26s), loss: 2839.39082605, reward: -2, running reward: -4.55861591888
# Episode 100 complete (0.17s), loss: 1736.11968545, reward: 4, running reward: -2.64692344873
# Episode 150 complete (0.27s), loss: 1577.22984707, reward: 0, running reward: 4.55481134503
# Episode 200 complete (0.21s), loss: 987.01536046, reward: 14, running reward: 10.5948074619
# Episode 250 complete (0.16s), loss: 445.479134792, reward: 40, running reward: 30.2489683131
# Episode 300 complete (0.23s), loss: 120.343305364, reward: 46, running reward: 43.8171651631
# /usr/local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# VirtualRat0-1
# Episode 50 complete (0.16s), loss: 2101.23091822, reward: 2, running reward: -8.05682542896
# Episode 100 complete (0.16s), loss: 1905.59073108, reward: -14, running reward: -2.10211152148
# Episode 150 complete (0.26s), loss: 1349.23475467, reward: 18, running reward: 7.64728825036
# Episode 200 complete (0.31s), loss: 715.575369942, reward: 28, running reward: 21.1754628786
# Episode 250 complete (0.18s), loss: 280.802505331, reward: 40, running reward: 38.0519424447
# Episode 300 complete (0.16s), loss: 94.0036778799, reward: 48, running reward: 45.7735772069
# VirtualRat0-2
# Episode 50 complete (0.21s), loss: 1760.12853198, reward: -10, running reward: -3.05621376713
# Episode 100 complete (0.18s), loss: 1675.6649364, reward: 6, running reward: 0.291402152379
# Episode 150 complete (0.16s), loss: 1341.62820216, reward: 14, running reward: 5.00867103942
# Episode 200 complete (0.17s), loss: 1154.56386293, reward: 12, running reward: 12.4986812233
# Episode 250 complete (0.20s), loss: 989.385048956, reward: 14, running reward: 17.6356881077
# Episode 300 complete (0.16s), loss: 1596.03951938, reward: 14, running reward: 18.0999655635
# VirtualRat0-3
# Episode 50 complete (0.15s), loss: 1984.99963498, reward: -12, running reward: -3.6452541968
# Episode 100 complete (0.15s), loss: 1619.66486481, reward: 2, running reward: 3.80863094405
# Episode 150 complete (0.17s), loss: 1558.5345772, reward: 6, running reward: 7.9181978958
# Episode 200 complete (0.16s), loss: 940.205977208, reward: 20, running reward: 14.7852477617
# Episode 250 complete (0.16s), loss: 406.962794934, reward: 36, running reward: 30.3125524263
# Episode 300 complete (0.15s), loss: 79.5710636897, reward: 40, running reward: 44.8300008394
# VirtualRat0-4
# Episode 50 complete (0.16s), loss: 2027.47798329, reward: -18, running reward: -5.7686854158
# Episode 100 complete (0.27s), loss: 1420.60774934, reward: -4, running reward: 3.56024829916
# Episode 150 complete (0.16s), loss: 1006.60226691, reward: 26, running reward: 14.5287091871
# Episode 200 complete (0.16s), loss: 466.560295513, reward: 36, running reward: 30.4406263825
# Episode 250 complete (0.17s), loss: 115.620770004, reward: 46, running reward: 41.4559464512
# Episode 300 complete (0.30s), loss: 34.2609807966, reward: 48, running reward: 48.2818117747
# dataProcessFunctions.py:429: RuntimeWarning: Mean of empty slice
#   pro_mean = np.nanmean(pro_matrix, axis = 0)
# VirtualRat1-0
# Episode 50 complete (0.31s), loss: 1902.11486667, reward: -4, running reward: -7.1399996757
# Episode 100 complete (0.21s), loss: 1724.28629183, reward: 10, running reward: 1.42413445457
# Episode 150 complete (0.31s), loss: 1377.40940542, reward: 4, running reward: 6.45690577584
# Episode 200 complete (0.18s), loss: 1024.96740942, reward: 14, running reward: 17.5325643261
# Episode 250 complete (0.62s), loss: 383.263025631, reward: 36, running reward: 30.655467833
# Episode 300 complete (0.28s), loss: 90.7084501352, reward: 50, running reward: 44.5999189495
# VirtualRat1-1
# Episode 50 complete (0.17s), loss: 1925.29509113, reward: 2, running reward: -4.2045490527
# Episode 100 complete (0.16s), loss: 1577.77193328, reward: 8, running reward: 6.18951120618
# Episode 150 complete (0.28s), loss: 1105.7267967, reward: 22, running reward: 14.905990727
# Episode 200 complete (0.16s), loss: 730.018295171, reward: 12, running reward: 23.8913887951
# Episode 250 complete (0.18s), loss: 81.5499945475, reward: 48, running reward: 45.3366458839
# Episode 300 complete (0.19s), loss: 22.3779616026, reward: 50, running reward: 48.9621043788
# VirtualRat1-2
# Episode 50 complete (0.16s), loss: 1855.91911424, reward: 4, running reward: -2.72128983496
# Episode 100 complete (0.21s), loss: 1441.67329609, reward: 8, running reward: 5.21648512658
# Episode 150 complete (0.17s), loss: 1024.62193771, reward: 18, running reward: 10.8561312052
# Episode 200 complete (0.16s), loss: 629.798028504, reward: 34, running reward: 26.4768072334
# Episode 250 complete (0.21s), loss: 137.245915751, reward: 46, running reward: 43.2811157133
# Episode 300 complete (0.18s), loss: 33.112836289, reward: 50, running reward: 47.9904119103
# VirtualRat1-3
# Episode 50 complete (0.16s), loss: 2094.70965016, reward: -14, running reward: -5.86433044519
# Episode 100 complete (0.16s), loss: 1785.15437438, reward: -6, running reward: 1.65638548502
# Episode 150 complete (0.18s), loss: 1081.24806663, reward: 8, running reward: 11.3476253263
# Episode 200 complete (0.20s), loss: 576.305829289, reward: 34, running reward: 26.0320315579
# Episode 250 complete (0.16s), loss: 255.943771683, reward: 46, running reward: 38.5347097918
# Episode 300 complete (0.20s), loss: 53.5161575784, reward: 46, running reward: 46.3768543098
# VirtualRat1-4
# Episode 50 complete (0.21s), loss: 1781.98886607, reward: 2, running reward: -3.03376084052
# Episode 100 complete (0.18s), loss: 1747.9084012, reward: -6, running reward: -0.567397041721
# Episode 150 complete (0.24s), loss: 1275.48996798, reward: 16, running reward: 6.3077282409
# Episode 200 complete (0.16s), loss: 651.482780194, reward: 32, running reward: 24.6014562105
# Episode 250 complete (0.22s), loss: 166.384658438, reward: 46, running reward: 42.8290349852
# Episode 300 complete (0.18s), loss: 40.2258721407, reward: 48, running reward: 48.1907930816

# %%
plt.plot(solver.temperature_history)
plt.xlabel('Iteration')
plt.ylabel('Temperature')
plt.title('Temperature history')
plt.show()

# %%
for k, v in solver.parameter_history.iteritems():
    print k
    print v[-1]

# %%
param = params2vector(solver.parameter_history,0)
num_parameter = param.shape[0]
all_parameters = np.zeros((0,5,num_parameter+1))
for vindex in range(len(all_solvers)):
    v = all_solvers[vindex]
    rats = all_rats[vindex]
    parameters = np.zeros((0,num_parameter+1))
    for kk, vv in v.iteritems():
        smallest = np.argmin(np.array([rats[kk].p2a_left_prob[3],rats[kk].p2a_right_prob[3],
                  rats[kk].a2p_left_prob[3],rats[kk].a2p_right_prob[3]]))
        params = params2vector(vv.parameter_history,-1)#index
        params = np.append(params,smallest)
        params_exp = np.expand_dims(params,axis=0)
        parameters = np.append(parameters,params_exp,axis=0)
    parameters_exp = np.expand_dims(parameters,axis=0)
    all_parameters = np.append(all_parameters,parameters_exp, axis=0)

# %%
save_weights("final_parameter_fixed_init_with_output3.pkl",all_parameters)
