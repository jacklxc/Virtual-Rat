# %%
import numpy as npp
import minpy.numpy as np
import cPickle
import matplotlib.pyplot as plt
import minpy
minpy.set_global_policy('only_numpy')

from SimplePolicyNetwork import SimplePolicyNetwork
from SimpleRLPolicyGradientSolver import SimpleRLPolicyGradientSolver
from simpleBox import simpleBox
from SimRat import SimRat
from dataProcessFunctions import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
box = simpleBox(mode="alternative",length=1000,block_size=30,random_range=0,trial_per_episode=5, repeat = True)
val_X, val_y = box.X,box.y
rats = {}
for i in range(5):
    ratname = 'VirtualRat'+str(i)
    model = SimplePolicyNetwork(hidden_dim=5,reg=0, noise_factor = 0)
    rat = SimRat(model)
    box = simpleBox(mode="pro_only",length=10000,block_size=30,random_range=0,
                    trial_per_episode=5, repeat = False, reward_ratio = 1, p2a = 0.5, correction = True)
    solver = SimpleRLPolicyGradientSolver(model, box,
                                        update_rule='adam',
                                        optim_config={
                                            'learning_rate': 0.01,
                                            'decay_rate': 1
                                        },
                                        init_rule='xavier',
                                        num_episodes=401,
                                        verbose=False,
                                        supervised = False,
                                        stop = False,
                                        print_every=100)
    solver.init()
    solver.set_temperature(3)
    #init_param = solver.save_params()
    #solver.load_params(loaded_params)
    solver.train()

    
    box.change_mode("alternative")
    solver.change_settings(learning_rate=0.01,num_episodes=3001)
    solver.set_temperature(6)
    solver.train()
    
    probs = rat.predict(val_X,val_y)
    trial_window = 3
    np.set_printoptions(precision=2)
    plt.ylim([0,1])
    draw_3d(rat.p2a_prob, rat.a2p_prob, trial_window = 3)

    rats[ratname] = rat
    #params[ratname] = init_param
    rat.addHistory(box.output_history())
    rat.computeLearningCurve(50)

trial_window = 3
p2a_mean, a2p_mean = meanPerformance(rats, trial_window = 3)
np.set_printoptions(precision=2)
plt.ylim([0,1])
draw_3d(p2a_mean, a2p_mean, trial_window = 3)
pro_mean, anti_mean = meanLearningCurve(rats)
learningCurve(pro_mean,anti_mean, rats)
# Out:
# Episode 100 complete (0.03s), loss: -1.99133306026, reward: -1, running reward: -2.48385350681
# Episode 200 complete (0.02s), loss: 5.96308311898, reward: 1, running reward: -0.695374572317
# Episode 300 complete (0.01s), loss: 1.84086080554, reward: 5, running reward: 1.40221713041
# Episode 400 complete (0.01s), loss: 0.87272399535, reward: 5, running reward: 3.32482093385
# Episode 100 complete (0.01s), loss: 3.72116729339, reward: 1, running reward: 0.166788671927
# Episode 200 complete (0.01s), loss: 5.03180937694, reward: 1, running reward: -0.294148125761
# Episode 300 complete (0.01s), loss: -5.00029215784, reward: -1, running reward: 0.0939951830899
# Episode 400 complete (0.01s), loss: 5.52839568225, reward: 1, running reward: -0.224702821313
# Episode 500 complete (0.01s), loss: -4.02876849856, reward: -1, running reward: -0.16541526158
# Episode 600 complete (0.01s), loss: 2.98963120479, reward: 1, running reward: -0.625407646067
# Episode 700 complete (0.01s), loss: 3.62079285717, reward: 1, running reward: -0.029251963248
# Episode 800 complete (0.01s), loss: -8.96612700476, reward: -3, running reward: -0.304595619319
# Episode 900 complete (0.01s), loss: -13.8000287298, reward: -5, running reward: 0.163845783589
# Episode 1000 complete (0.01s), loss: 7.61973725221, reward: 1, running reward: 0.410222633615
# Episode 1100 complete (0.01s), loss: -1.0971535122, reward: -1, running reward: 0.0409485457681
# Episode 1200 complete (0.01s), loss: 2.61739339196, reward: 1, running reward: 0.221516695111
# Episode 1300 complete (0.01s), loss: -2.60746987799, reward: -1, running reward: -0.2906320735
# Episode 1400 complete (0.02s), loss: 7.75587678898, reward: 3, running reward: -0.222079160251
# Episode 1500 complete (0.03s), loss: 3.86872123323, reward: 1, running reward: 0.219245732412
# Episode 1600 complete (0.01s), loss: 3.46114273815, reward: 1, running reward: -0.176513490745
# Episode 1700 complete (0.01s), loss: -3.41108144463, reward: -1, running reward: -0.119694387484
# Episode 1800 complete (0.01s), loss: 16.1978162767, reward: 5, running reward: 0.0740266004154
# Episode 1900 complete (0.01s), loss: 3.41682806652, reward: 1, running reward: -0.00694233779063
# Episode 2000 complete (0.01s), loss: 3.83045106862, reward: 1, running reward: 0.296574969928
# Episode 2100 complete (0.02s), loss: 12.4922502116, reward: 3, running reward: -0.0214492413419
# Episode 2200 complete (0.02s), loss: -3.47349295514, reward: -1, running reward: -0.232278778837
# Episode 2300 complete (0.02s), loss: -3.7269922317, reward: -1, running reward: 0.220232930254
# Episode 2400 complete (0.01s), loss: 1.92320724274, reward: 5, running reward: 0.789890742527
# Episode 2500 complete (0.02s), loss: 9.21231312909, reward: 3, running reward: 0.45012114743
# Episode 2600 complete (0.01s), loss: -3.24562761898, reward: -1, running reward: 0.461713381955
# Episode 2700 complete (0.01s), loss: 3.46723164457, reward: 1, running reward: 0.668796811476
# Episode 2800 complete (0.01s), loss: 3.53735863256, reward: 1, running reward: 1.72969757267
# Episode 2900 complete (0.01s), loss: 3.09521096041, reward: 5, running reward: 2.63418417254
# Episode 3000 complete (0.02s), loss: 0.183917486194, reward: 5, running reward: 3.70951065896
# /usr/local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Episode 100 complete (0.01s), loss: -10.6824409074, reward: -3, running reward: -1.80034161188
# Episode 200 complete (0.01s), loss: 11.790249298, reward: 5, running reward: -0.111393610255
# Episode 300 complete (0.01s), loss: 1.31079128974, reward: 5, running reward: 2.0973599276
# Episode 400 complete (0.02s), loss: 0.0893482397862, reward: 5, running reward: 3.84100515661
# Episode 100 complete (0.02s), loss: -5.41305528769, reward: -1, running reward: 1.16640844215
# Episode 200 complete (0.01s), loss: 11.4582514928, reward: 3, running reward: 0.236914539661
# Episode 300 complete (0.04s), loss: 18.0355986655, reward: 5, running reward: 0.0823541022561
# Episode 400 complete (0.01s), loss: -10.9372121028, reward: -3, running reward: 0.0485215997272
# Episode 500 complete (0.01s), loss: 18.5441870141, reward: 3, running reward: -0.166721753716
# Episode 600 complete (0.01s), loss: -3.13969701168, reward: -1, running reward: -0.0671245148157
# Episode 700 complete (0.02s), loss: 5.02580708569, reward: 1, running reward: -0.317625126711
# Episode 800 complete (0.02s), loss: 3.34035783626, reward: 1, running reward: 0.382894790874
# Episode 900 complete (0.03s), loss: -11.326129871, reward: -3, running reward: 0.444495884335
# Episode 1000 complete (0.01s), loss: 3.6474560785, reward: 1, running reward: 0.361796472745
# Episode 1100 complete (0.03s), loss: 4.65012947489, reward: 1, running reward: 0.288643395823
# Episode 1200 complete (0.03s), loss: 10.2416071061, reward: 3, running reward: 0.325347646973
# Episode 1300 complete (0.02s), loss: -10.182014494, reward: -3, running reward: 0.349615629992
# Episode 1400 complete (0.01s), loss: -3.44719454679, reward: -1, running reward: 0.220309551378
# Episode 1500 complete (0.01s), loss: -3.79763612535, reward: -1, running reward: 0.551866761501
# Episode 1600 complete (0.02s), loss: 8.27584394901, reward: 3, running reward: 1.2885539863
# Episode 1700 complete (0.01s), loss: 3.0539767852, reward: 1, running reward: 1.81662122905
# Episode 1800 complete (0.02s), loss: 7.69233222426, reward: 3, running reward: 2.24503495341
# Episode 1900 complete (0.01s), loss: 5.16018256364, reward: 5, running reward: 3.18359835213
# Episode 2000 complete (0.01s), loss: 0.624984201334, reward: 5, running reward: 3.80978781783
# Episode 2100 complete (0.01s), loss: 0.0110133136172, reward: 5, running reward: 4.40142386387
# Episode 2200 complete (0.01s), loss: 0.794050273372, reward: 5, running reward: 4.63881784211
# Episode 2300 complete (0.01s), loss: 0.0148203236219, reward: 5, running reward: 4.7944615476
# Episode 2400 complete (0.01s), loss: 0.0325409815163, reward: 5, running reward: 4.84082071902
# Episode 2500 complete (0.01s), loss: 0.217377508775, reward: 5, running reward: 4.90454300263
# Episode 2600 complete (0.01s), loss: 0.00635985884524, reward: 5, running reward: 4.96505965176
# Episode 2700 complete (0.01s), loss: 0.00480134846784, reward: 5, running reward: 4.98721070253
# Episode 2800 complete (0.01s), loss: 0.0161465869499, reward: 5, running reward: 4.9953187035
# Episode 2900 complete (0.01s), loss: 0.00123458049242, reward: 5, running reward: 4.99828649408
# Episode 3000 complete (0.01s), loss: 0.000806350336946, reward: 5, running reward: 4.99937280142
# Episode 100 complete (0.01s), loss: 11.5584392759, reward: 3, running reward: -0.590270847271
# Episode 200 complete (0.01s), loss: 8.68085722405, reward: 3, running reward: 1.52065398481
# Episode 300 complete (0.02s), loss: 0.488118684636, reward: 5, running reward: 3.42271187024
# Episode 400 complete (0.01s), loss: 0.221951061225, reward: 5, running reward: 4.32044204128
# Episode 100 complete (0.01s), loss: 3.06250141952, reward: 1, running reward: 0.732286391987
# Episode 200 complete (0.01s), loss: -4.00350379999, reward: -1, running reward: -0.262779053422
# Episode 300 complete (0.01s), loss: -3.03416855152, reward: -3, running reward: -0.579599542476
# Episode 400 complete (0.02s), loss: -13.8021500719, reward: -5, running reward: -0.640658402004
# Episode 500 complete (0.01s), loss: 13.6542761558, reward: 5, running reward: -0.512556793598
# Episode 600 complete (0.01s), loss: 2.73130818393, reward: 1, running reward: 0.303666938904
# Episode 700 complete (0.01s), loss: -2.63213771517, reward: -1, running reward: 0.241916516067
# Episode 800 complete (0.01s), loss: 0.725514021708, reward: 1, running reward: 0.0114965358169
# Episode 900 complete (0.01s), loss: -2.58885689302, reward: -3, running reward: 0.698174249043
# Episode 1000 complete (0.02s), loss: 3.73513352868, reward: 1, running reward: -0.0778314994051
# Episode 1100 complete (0.01s), loss: 1.06877018948, reward: 1, running reward: 0.539478534136
# Episode 1200 complete (0.01s), loss: -5.40192644822, reward: -1, running reward: 1.10666152295
# Episode 1300 complete (0.01s), loss: 5.4858389537, reward: 3, running reward: 0.84655770883
# Episode 1400 complete (0.01s), loss: 5.17619618285, reward: 3, running reward: 1.68873615296
# Episode 1500 complete (0.01s), loss: 4.46227652927, reward: 5, running reward: 2.11557158355
# Episode 1600 complete (0.01s), loss: 3.48994477172, reward: 5, running reward: 2.43536841087
# Episode 1700 complete (0.01s), loss: 3.91188161531, reward: 1, running reward: 3.36768453356
# Episode 1800 complete (0.01s), loss: 1.85146648856, reward: 5, running reward: 4.01319569131
# Episode 1900 complete (0.01s), loss: 0.601788738186, reward: 5, running reward: 4.3330511151
# Episode 2000 complete (0.01s), loss: 0.570271884103, reward: 5, running reward: 4.60828924286
# Episode 2100 complete (0.01s), loss: 0.459341623284, reward: 5, running reward: 4.75028356016
# Episode 2200 complete (0.01s), loss: 0.270538195082, reward: 5, running reward: 4.79294191539
# Episode 2300 complete (0.01s), loss: 0.238583220275, reward: 5, running reward: 4.82448839134
# Episode 2400 complete (0.01s), loss: 0.276401166462, reward: 5, running reward: 4.87092585659
# Episode 2500 complete (0.01s), loss: 0.0896148222198, reward: 5, running reward: 4.93333053482
# Episode 2600 complete (0.01s), loss: 0.269087766857, reward: 5, running reward: 4.88017717998
# Episode 2700 complete (0.01s), loss: 0.0926996721867, reward: 5, running reward: 4.95614097265
# Episode 2800 complete (0.01s), loss: 0.0932776221757, reward: 5, running reward: 4.93768075468
# Episode 2900 complete (0.01s), loss: 0.0749340798823, reward: 5, running reward: 4.96823867645
# Episode 3000 complete (0.01s), loss: 0.0327970187588, reward: 5, running reward: 4.98837432838
# Episode 100 complete (0.01s), loss: 2.67849598587, reward: 1, running reward: 1.71605904074
# Episode 200 complete (0.01s), loss: 3.35346271934, reward: 1, running reward: 1.5841813094
# Episode 300 complete (0.01s), loss: 1.26888475107, reward: 5, running reward: 2.93160122836
# Episode 400 complete (0.02s), loss: 0.504009426696, reward: 5, running reward: 4.03553152873
# Episode 100 complete (0.01s), loss: -2.96976150417, reward: -1, running reward: 0.855173755182
# Episode 200 complete (0.01s), loss: 4.04823102075, reward: 1, running reward: 0.015411096907
# Episode 300 complete (0.02s), loss: -3.09866631895, reward: -3, running reward: -0.334036468741
# Episode 400 complete (0.02s), loss: -12.3429032765, reward: -3, running reward: -0.186911026471
# Episode 500 complete (0.01s), loss: 6.130508454, reward: 1, running reward: -0.289926708804
# Episode 600 complete (0.01s), loss: -2.64641984939, reward: -1, running reward: -0.154394793175
# Episode 700 complete (0.01s), loss: 20.2087152692, reward: 5, running reward: -0.159358202431
# Episode 800 complete (0.01s), loss: -3.62676183812, reward: -1, running reward: -0.178293147031
# Episode 900 complete (0.01s), loss: -8.58477118013, reward: -3, running reward: 0.0918808235173
# Episode 1000 complete (0.01s), loss: -3.49870807721, reward: -1, running reward: 0.276592006641
# Episode 1100 complete (0.01s), loss: 8.04660766993, reward: 5, running reward: 0.4841328432
# Episode 1200 complete (0.01s), loss: 8.18387218738, reward: 3, running reward: 1.18711491881
# Episode 1300 complete (0.01s), loss: 4.49448657275, reward: 5, running reward: 1.79916411648
# Episode 1400 complete (0.01s), loss: 4.84205942314, reward: 5, running reward: 2.29695113722
# Episode 1500 complete (0.01s), loss: 8.24948648028, reward: 3, running reward: 2.60778695844
# Episode 1600 complete (0.01s), loss: 4.43238396276, reward: 1, running reward: 3.21933422467
# Episode 1700 complete (0.01s), loss: 1.38639601263, reward: 5, running reward: 3.81071235399
# Episode 1800 complete (0.01s), loss: 0.428293386757, reward: 5, running reward: 4.38656985672
# Episode 1900 complete (0.01s), loss: 1.34960979042, reward: 5, running reward: 4.6056395719
# Episode 2000 complete (0.01s), loss: 0.196520002337, reward: 5, running reward: 4.77651361853
# Episode 2100 complete (0.01s), loss: 0.0873859661116, reward: 5, running reward: 4.87657078981
# Episode 2200 complete (0.01s), loss: 0.0826647959269, reward: 5, running reward: 4.94430898746
# Episode 2300 complete (0.02s), loss: 0.0204619447609, reward: 5, running reward: 4.97961528829
# Episode 2400 complete (0.01s), loss: 0.0112680403574, reward: 5, running reward: 4.99253853625
# Episode 2500 complete (0.02s), loss: 0.0129352314957, reward: 5, running reward: 4.99726886295
# Episode 2600 complete (0.01s), loss: 0.0049582359524, reward: 5, running reward: 4.99900031551
# Episode 2700 complete (0.01s), loss: 0.00303587494494, reward: 5, running reward: 4.99963408315
# Episode 2800 complete (0.01s), loss: 0.00313357154307, reward: 5, running reward: 4.9998660626
# Episode 2900 complete (0.01s), loss: 0.00105543722521, reward: 5, running reward: 4.99995097458
# Episode 3000 complete (0.01s), loss: 0.00118088482087, reward: 5, running reward: 4.99998205511
# Episode 100 complete (0.01s), loss: -5.69480465449, reward: -1, running reward: 1.25162346649
# Episode 200 complete (0.03s), loss: 7.25264843908, reward: 3, running reward: 2.22414362536
# Episode 300 complete (0.01s), loss: 0.377038357862, reward: 5, running reward: 3.70914281339
# Episode 400 complete (0.02s), loss: 18.2053737269, reward: 3, running reward: 4.4718761211
# Episode 100 complete (0.01s), loss: -6.2874166171, reward: -5, running reward: 0.634617873739
# Episode 200 complete (0.01s), loss: 5.01669867686, reward: 3, running reward: -0.329572315185
# Episode 300 complete (0.02s), loss: -3.46239166761, reward: -1, running reward: -0.483469673877
# Episode 400 complete (0.01s), loss: -4.03155563435, reward: -5, running reward: -0.581305436508
# Episode 500 complete (0.02s), loss: 0.854524948444, reward: 1, running reward: -0.111896841414
# Episode 600 complete (0.01s), loss: 0.707547067052, reward: 1, running reward: -0.184804710499
# Episode 700 complete (0.01s), loss: -6.7160379671, reward: -1, running reward: -0.239040375371
# Episode 800 complete (0.01s), loss: -0.567671089112, reward: -1, running reward: 0.212551607812
# Episode 900 complete (0.01s), loss: -0.441196761295, reward: -1, running reward: 0.438252141415
# Episode 1000 complete (0.01s), loss: 1.15218288115, reward: 3, running reward: 0.465438870597
# Episode 1100 complete (0.01s), loss: 6.92926365602, reward: 1, running reward: 0.428054056673
# Episode 1200 complete (0.01s), loss: -0.26352661334, reward: -1, running reward: 0.484476657932
# Episode 1300 complete (0.01s), loss: 0.63236452773, reward: 3, running reward: 0.601816355347
# Episode 1400 complete (0.01s), loss: 0.851731188916, reward: 5, running reward: 0.509452785844
# Episode 1500 complete (0.02s), loss: -0.116364911605, reward: -1, running reward: 0.497657584695
# Episode 1600 complete (0.01s), loss: 0.27983611811, reward: 3, running reward: 0.682370212945
# Episode 1700 complete (0.01s), loss: 0.48998348964, reward: 5, running reward: 0.634109001854
# Episode 1800 complete (0.01s), loss: -0.088348734633, reward: -1, running reward: 0.547123677385
# Episode 1900 complete (0.01s), loss: 0.25832802625, reward: 3, running reward: 0.623820741798
# Episode 2000 complete (0.01s), loss: 0.402945991679, reward: 5, running reward: 0.605665617213
# Episode 2100 complete (0.01s), loss: -0.0583235780682, reward: -1, running reward: 0.614782951377
# Episode 2200 complete (0.01s), loss: 0.174965255431, reward: 3, running reward: 0.626291283653
# Episode 2300 complete (0.01s), loss: 0.20346827708, reward: 5, running reward: 0.639169950739
# Episode 2400 complete (0.01s), loss: -0.0413432459776, reward: -1, running reward: 0.576227256613
# Episode 2500 complete (0.01s), loss: 0.087068274809, reward: 3, running reward: 0.634489893829
# Episode 2600 complete (0.01s), loss: 0.117735550451, reward: 5, running reward: 0.620901120838
# Episode 2700 complete (0.01s), loss: -0.0195165698931, reward: -1, running reward: 0.608698912484
# Episode 2800 complete (0.01s), loss: 0.0700954152179, reward: 3, running reward: 0.685960727603
# Episode 2900 complete (0.01s), loss: 0.0733433492632, reward: 5, running reward: 0.671823418718
# Episode 3000 complete (0.01s), loss: -0.0123046812784, reward: -1, running reward: 0.631020644726
# dataProcessFunctions.py:415: RuntimeWarning: Mean of empty slice
#   pro_mean = np.nanmean(pro_matrix, axis = 0)
# dataProcessFunctions.py:416: RuntimeWarning: Mean of empty slice
#   anti_mean = np.nanmean(anti_matrix, axis = 0)

# %%
plt.plot(solver.temperature_history)
plt.xlabel('Iteration')
plt.ylabel('Temperature')
plt.title('Temperature history')
plt.show()
