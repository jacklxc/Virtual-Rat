# %%
import numpy as npp
import minpy.numpy as np
import cPickle
import matplotlib.pyplot as plt
import minpy
minpy.set_global_policy('only_numpy')

from SimplePolicyNetwork import SimplePolicyNetwork
from SimpleRLPolicyGradientSolver import SimpleRLPolicyGradientSolver
from simpleBox import simpleBox
from SimRat import SimRat
from dataProcessFunctions import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# Good weights #4 is good!
weight_file = "combo_weights/combo_weight"
loaded_params = load_weights(weight_file+"2.pkl")

# %%
box = simpleBox(mode="alternative",length=1000,block_size=30,random_range=0,trial_per_episode=5, repeat = True)
val_X, val_y = box.X,box.y
rats = {}
#params = {}
for i in range(11):
    ratname = 'VirtualRat'+str(i)
    p2a_ratio = 1
    print ratname, p2a_ratio
    model = SimplePolicyNetwork(hidden_dim=5,reg=0, noise_factor = 0)
    rat = SimRat(model)
    box = simpleBox(mode="switch_ratio",length=10000,block_size=30,random_range=0,
                    trial_per_episode=5, repeat = True, reward_ratio = 1, p2a = p2a_ratio, correction = True)
    solver = SimpleRLPolicyGradientSolver(model, box,
                                        update_rule='adam',
                                        optim_config={
                                            'learning_rate': 0.01,
                                            'decay_rate': 1
                                        },
                                        init_rule='xavier',
                                        num_episodes=1501,
                                        verbose=False,
                                        supervised = False,
                                        print_every=100)
    #solver.init()
    #init_param = solver.save_params()
    solver.load_params(loaded_params)
    solver.train()

    
    probs = rat.predict(val_X,val_y)
    trial_window = 3
    np.set_printoptions(precision=2)
    plt.ylim([0,1])
    draw_3d(rat.p2a_prob, rat.a2p_prob, trial_window = 3)

    rats[ratname] = rat
    #params[ratname] = init_param
    rat.addHistory(box.output_history())
    rat.computeLearningCurve()
    
trial_window = 3
p2a_mean, a2p_mean = meanPerformance(rats, trial_window = 3)
np.set_printoptions(precision=2)
plt.ylim([0,1])
draw_3d(p2a_mean, a2p_mean, trial_window = 3)
pro_mean, anti_mean = meanLearningCurve(rats)
learningCurve(pro_mean,anti_mean, rats)
# Out:
# VirtualRat0 1
# Episode 100 complete (0.01s), loss: -0.470849436686, reward: -1, running reward: -0.192458386364
# Episode 200 complete (0.01s), loss: 3.04768407208, reward: 1, running reward: 0.118204471472
# Episode 300 complete (0.01s), loss: 3.39543353104, reward: 5, running reward: 1.20683403139
# Episode 400 complete (0.01s), loss: 2.58247642971, reward: 1, running reward: 1.81309371932
# Episode 500 complete (0.01s), loss: -1.8292148284, reward: -1, running reward: 2.20180746093
# Episode 600 complete (0.01s), loss: 4.28633113765, reward: 5, running reward: 2.80761147327
# Episode 700 complete (0.01s), loss: 6.8084530658, reward: 1, running reward: 3.04460087706
# Episode 800 complete (0.01s), loss: 2.9000524118, reward: 5, running reward: 3.40010374602
# Episode 900 complete (0.01s), loss: 1.97207203225, reward: 5, running reward: 3.65089385339
# Episode 1000 complete (0.01s), loss: 10.1217096599, reward: 3, running reward: 3.84931169321
# Episode 1100 complete (0.01s), loss: 9.94623243491, reward: 3, running reward: 3.94385581512
# Episode 1200 complete (0.01s), loss: 1.12657472, reward: 5, running reward: 3.96249212721
# Episode 1300 complete (0.01s), loss: 0.375754763777, reward: 3, running reward: 4.00762142448
# Episode 1400 complete (0.01s), loss: 0.831755479164, reward: 5, running reward: 4.01005561238
# Episode 1500 complete (0.01s), loss: 0.806074880101, reward: 5, running reward: 4.1946232547
# VirtualRat1 1
# Episode 100 complete (0.01s), loss: 0.0757796673968, reward: 1, running reward: 2.07705564119
# Episode 200 complete (0.01s), loss: 0.0261826532425, reward: 1, running reward: 1.16380507998
# Episode 300 complete (0.01s), loss: -0.00993861769407, reward: -1, running reward: 0.784685907971
# Episode 400 complete (0.01s), loss: 0.00611077473038, reward: 1, running reward: 0.711011637587
# Episode 500 complete (0.01s), loss: 0.0056408744835, reward: 1, running reward: 0.683742763434
# Episode 600 complete (0.01s), loss: -0.00656565531759, reward: -1, running reward: 0.64928589438
# Episode 700 complete (0.01s), loss: 0.00453940411292, reward: 1, running reward: 0.679905747493
# Episode 800 complete (0.01s), loss: 0.00455523266147, reward: 1, running reward: 0.672357001656
# Episode 900 complete (0.01s), loss: -0.00440697442438, reward: -1, running reward: 0.628089181917
# Episode 1000 complete (0.01s), loss: 0.0011340245387, reward: 1, running reward: 0.664449143625
# Episode 1100 complete (0.02s), loss: 0.001170827253, reward: 1, running reward: 0.666699384754
# Episode 1200 complete (0.01s), loss: -0.00174110631996, reward: -1, running reward: 0.643047466578
# Episode 1300 complete (0.01s), loss: 0.00107215747726, reward: 1, running reward: 0.677622281158
# Episode 1400 complete (0.01s), loss: 0.00110409139271, reward: 1, running reward: 0.671521179127
# Episode 1500 complete (0.01s), loss: -0.00166863901336, reward: -1, running reward: 0.644812399262
# VirtualRat2 1
# Episode 100 complete (0.01s), loss: 0.338238954509, reward: 1, running reward: 0.367465218238
# Episode 200 complete (0.01s), loss: 0.592998093855, reward: 1, running reward: -0.00516170560981
# Episode 300 complete (0.01s), loss: 5.72799154149, reward: 1, running reward: 0.122608887838
# Episode 400 complete (0.01s), loss: -5.21319451899, reward: -1, running reward: 0.525150984103
# Episode 500 complete (0.01s), loss: -5.33546715627, reward: -1, running reward: 1.24088118433
# Episode 600 complete (0.01s), loss: 3.76511804302, reward: 5, running reward: 2.2526025513
# Episode 700 complete (0.01s), loss: 3.24306703532, reward: 5, running reward: 2.67969013652
# Episode 800 complete (0.01s), loss: 3.2081135078, reward: 1, running reward: 3.0044985548
# Episode 900 complete (0.01s), loss: 6.24506256199, reward: 3, running reward: 3.3570701709
# Episode 1000 complete (0.02s), loss: 0.9043496853, reward: 3, running reward: 3.57281882968
# Episode 1100 complete (0.01s), loss: 1.53279885984, reward: 5, running reward: 3.89163284408
# Episode 1200 complete (0.01s), loss: 1.58587420679, reward: 5, running reward: 3.9857815254
# Episode 1300 complete (0.01s), loss: 0.359723747846, reward: 3, running reward: 4.12482017762
# Episode 1400 complete (0.01s), loss: 0.620826276558, reward: 5, running reward: 4.17435876719
# Episode 1500 complete (0.01s), loss: 1.45926981822, reward: 5, running reward: 4.11272198357
# /usr/local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# VirtualRat3 1
# Episode 100 complete (0.01s), loss: 0.147422867377, reward: 3, running reward: 0.60902524031
# Episode 200 complete (0.01s), loss: -0.437588309797, reward: -1, running reward: 0.444131435002
# Episode 300 complete (0.01s), loss: -0.0364796169745, reward: -1, running reward: -0.0908897524351
# Episode 400 complete (0.01s), loss: -0.0291406752845, reward: -1, running reward: -0.278204594803
# Episode 500 complete (0.01s), loss: -0.066279428824, reward: -1, running reward: -0.306186318491
# Episode 600 complete (0.01s), loss: -0.0926685673237, reward: -1, running reward: -0.300468601393
# Episode 700 complete (0.01s), loss: 0.0801360982101, reward: 1, running reward: 0.190475788048
# Episode 800 complete (0.01s), loss: 0.198427640979, reward: 5, running reward: 1.10079151393
# Episode 900 complete (0.01s), loss: -0.00991004856596, reward: -1, running reward: 1.65158089157
# Episode 1000 complete (0.01s), loss: 0.0419191769633, reward: 3, running reward: 1.8889128029
# Episode 1100 complete (0.02s), loss: 0.0567523891466, reward: 5, running reward: 1.94448604499
# Episode 1200 complete (0.01s), loss: -0.00482912673324, reward: -1, running reward: 1.96040037609
# Episode 1300 complete (0.01s), loss: 0.0144141805812, reward: 3, running reward: 2.01405084319
# Episode 1400 complete (0.01s), loss: 0.024431376356, reward: 5, running reward: 1.9809753234
# Episode 1500 complete (0.01s), loss: -0.00363264193753, reward: -1, running reward: 1.99148432953
# VirtualRat4 1
# Episode 100 complete (0.01s), loss: -5.16390105221, reward: -3, running reward: 0.0169119175008
# Episode 200 complete (0.01s), loss: 4.20503171182, reward: 3, running reward: 0.127905937244
# Episode 300 complete (0.01s), loss: -6.31620287082, reward: -3, running reward: 0.241196951908
# Episode 400 complete (0.01s), loss: 7.21426920254, reward: 5, running reward: 1.18413982947
# Episode 500 complete (0.01s), loss: 4.93386168328, reward: 5, running reward: 2.35961508221
# Episode 600 complete (0.01s), loss: 8.74530423295, reward: 3, running reward: 2.81626872853
# Episode 700 complete (0.02s), loss: 1.50182111666, reward: 3, running reward: 2.90537027626
# Episode 800 complete (0.01s), loss: 4.53050984502, reward: 5, running reward: 3.33462272112
# Episode 900 complete (0.01s), loss: 2.03376962937, reward: 5, running reward: 3.54381074013
# Episode 1000 complete (0.01s), loss: 1.22290870943, reward: 5, running reward: 3.73611815317
# Episode 1100 complete (0.01s), loss: 1.50776432177, reward: 5, running reward: 3.79864783203
# Episode 1200 complete (0.01s), loss: 7.40119748349, reward: 3, running reward: 3.84908435784
# Episode 1300 complete (0.02s), loss: 20.5620311946, reward: 5, running reward: 3.99430084482
# Episode 1400 complete (0.01s), loss: 4.48288939173, reward: 1, running reward: 4.04653476454
# Episode 1500 complete (0.01s), loss: 0.746448831358, reward: 5, running reward: 4.1044955103
# VirtualRat5 1
# Episode 100 complete (0.01s), loss: 0.017848008238, reward: 1, running reward: 1.5720615555
# Episode 200 complete (0.01s), loss: 0.0297000960221, reward: 1, running reward: 0.99146987842
# Episode 300 complete (0.01s), loss: 0.0405779436451, reward: 1, running reward: 0.559117608126
# Episode 400 complete (0.01s), loss: 0.0143137161509, reward: 1, running reward: 0.385361602418
# Episode 500 complete (0.01s), loss: 0.00885318177043, reward: 1, running reward: 0.34148751761
# Episode 600 complete (0.01s), loss: 0.00354010354389, reward: 1, running reward: 0.345146658313
# Episode 700 complete (0.01s), loss: 0.00755178807124, reward: 1, running reward: 0.330689278728
# Episode 800 complete (0.01s), loss: 0.00657003383971, reward: 1, running reward: 0.336876541883
# Episode 900 complete (0.01s), loss: 0.00288205514773, reward: 1, running reward: 0.343458892072
# Episode 1000 complete (0.01s), loss: 0.00593383896893, reward: 1, running reward: 0.330071501699
# Episode 1100 complete (0.02s), loss: 0.00391715470816, reward: 1, running reward: 0.323135834529
# Episode 1200 complete (0.01s), loss: 0.00196677835007, reward: 1, running reward: 0.338429348789
# Episode 1300 complete (0.01s), loss: 0.00369217915343, reward: 1, running reward: 0.328230526195
# Episode 1400 complete (0.01s), loss: 0.00243625478412, reward: 1, running reward: 0.328581966184
# Episode 1500 complete (0.01s), loss: 0.00136640155412, reward: 1, running reward: 0.340422809109
# VirtualRat6 1
# Episode 100 complete (0.01s), loss: -2.55417895178, reward: -1, running reward: -0.65939114346
# Episode 200 complete (0.01s), loss: 0.915864663379, reward: 1, running reward: 0.345294365107
# Episode 300 complete (0.01s), loss: 4.36623619182, reward: 1, running reward: 0.975952338476
# Episode 400 complete (0.02s), loss: 11.2041076645, reward: 3, running reward: 1.5349073785
# Episode 500 complete (0.01s), loss: -4.86604340315, reward: -1, running reward: 2.05838056321
# Episode 600 complete (0.01s), loss: 6.40373929287, reward: 3, running reward: 2.66463537727
# Episode 700 complete (0.01s), loss: 1.07322968374, reward: 3, running reward: 3.00371316809
# Episode 800 complete (0.01s), loss: 2.37376351082, reward: 5, running reward: 3.40813723088
# Episode 900 complete (0.01s), loss: 6.51592088884, reward: 5, running reward: 3.59192455439
# Episode 1000 complete (0.01s), loss: 1.27528072803, reward: 5, running reward: 3.80129381586
# Episode 1100 complete (0.01s), loss: 0.906093646689, reward: 5, running reward: 3.94502641835
# Episode 1200 complete (0.02s), loss: 1.36290658961, reward: 5, running reward: 3.93130892274
# Episode 1300 complete (0.01s), loss: 0.304556301765, reward: 3, running reward: 4.01636253793
# Episode 1400 complete (0.01s), loss: 1.02877773759, reward: 5, running reward: 4.02813906288
# Episode 1500 complete (0.01s), loss: 1.01517443561, reward: 5, running reward: 4.07565709695
# VirtualRat7 1
# Episode 100 complete (0.01s), loss: 0.027126729658, reward: 1, running reward: 0.383547144285
# Episode 200 complete (0.01s), loss: 0.00657099097483, reward: 1, running reward: 0.118116475897
# Episode 300 complete (0.01s), loss: -0.00653232758235, reward: -1, running reward: 0.0241142922963
# Episode 400 complete (0.01s), loss: 0.00638168711306, reward: 1, running reward: 0.0372562462841
# Episode 500 complete (0.01s), loss: 0.00672809913205, reward: 1, running reward: 0.00751328068631
# Episode 600 complete (0.01s), loss: -0.0810870581543, reward: -1, running reward: 0.0316808337181
# Episode 700 complete (0.01s), loss: 0.127788416409, reward: 1, running reward: 0.0502547339346
# Episode 800 complete (0.01s), loss: 0.503919697639, reward: 3, running reward: 0.128187686909
# Episode 900 complete (0.01s), loss: -2.08381931802, reward: -3, running reward: 0.207019055661
# Episode 1000 complete (0.01s), loss: -0.156141648144, reward: -3, running reward: -0.0761177731116
# Episode 1100 complete (0.01s), loss: -0.0328054428915, reward: -1, running reward: -0.226359157211
# Episode 1200 complete (0.01s), loss: -0.0110806766275, reward: -1, running reward: -0.362076931642
# Episode 1300 complete (0.01s), loss: -0.013236493927, reward: -3, running reward: -0.363670014708
# Episode 1400 complete (0.01s), loss: -0.168923466056, reward: -1, running reward: -0.304140223546
# Episode 1500 complete (0.01s), loss: -0.0755872275953, reward: -1, running reward: -0.309842620459
# VirtualRat8 1
# Episode 100 complete (0.01s), loss: 0.0162939317143, reward: 1, running reward: 0.0338769734854
# Episode 200 complete (0.01s), loss: 0.00754133612867, reward: 1, running reward: 0.431571965206
# Episode 300 complete (0.01s), loss: -0.00480747931877, reward: -1, running reward: 0.572779970127
# Episode 400 complete (0.01s), loss: 0.00373606310879, reward: 1, running reward: 0.640422973264
# Episode 500 complete (0.01s), loss: 0.00127021322935, reward: 1, running reward: 0.642753716075
# Episode 600 complete (0.01s), loss: -0.00779075024503, reward: -1, running reward: 0.64233664976
# Episode 700 complete (0.01s), loss: 0.00386758914889, reward: 1, running reward: 0.665882967561
# Episode 800 complete (0.02s), loss: 0.0030866835458, reward: 1, running reward: 0.662906598916
# Episode 900 complete (0.01s), loss: -0.00233026539376, reward: -1, running reward: 0.657455927722
# Episode 1000 complete (0.01s), loss: 0.00217062903828, reward: 1, running reward: 0.671417112272
# Episode 1100 complete (0.01s), loss: 0.00188219422557, reward: 1, running reward: 0.664932274861
# Episode 1200 complete (0.01s), loss: -0.000531757843736, reward: -1, running reward: 0.644817955459
# Episode 1300 complete (0.01s), loss: 0.000521096300073, reward: 1, running reward: 0.666791205695
# Episode 1400 complete (0.01s), loss: 0.000512554597372, reward: 1, running reward: 0.663239043447
# Episode 1500 complete (0.01s), loss: -0.000458574513236, reward: -1, running reward: 0.657577613172
# VirtualRat9 1
# Episode 100 complete (0.01s), loss: 0.0255840195926, reward: 1, running reward: -0.168640858696
# Episode 200 complete (0.02s), loss: -0.0348487503304, reward: -1, running reward: 0.163335341966
# Episode 300 complete (0.01s), loss: -0.0156714213045, reward: -1, running reward: 0.261627111968
# Episode 400 complete (0.01s), loss: -0.0159395409835, reward: -1, running reward: 0.289743632802
# Episode 500 complete (0.01s), loss: -0.00598482752005, reward: -1, running reward: 0.288944059584
# Episode 600 complete (0.01s), loss: -0.00434936483881, reward: -1, running reward: 0.315224907324
# Episode 700 complete (0.01s), loss: -0.00677502101446, reward: -1, running reward: 0.329162159323
# Episode 800 complete (0.02s), loss: -0.169272181188, reward: -1, running reward: 0.382077071031
# Episode 900 complete (0.01s), loss: -4.22572204724, reward: -1, running reward: 0.0883053787587
# Episode 1000 complete (0.01s), loss: -0.998797872802, reward: -1, running reward: -0.252348822868
# Episode 1100 complete (0.01s), loss: 5.68541036515, reward: 3, running reward: 0.396973339936
# Episode 1200 complete (0.01s), loss: 4.51823189789, reward: 3, running reward: 1.35750819525
# Episode 1300 complete (0.01s), loss: 8.38404517589, reward: 3, running reward: 2.54718182947
# Episode 1400 complete (0.01s), loss: 0.946369035627, reward: 3, running reward: 3.04628719487
# Episode 1500 complete (0.01s), loss: 1.70486415912, reward: 5, running reward: 3.50405712525
# VirtualRat10 1
# Episode 100 complete (0.01s), loss: 0.0751018766859, reward: 3, running reward: 0.287901614786
# Episode 200 complete (0.01s), loss: 0.388785099419, reward: 3, running reward: 0.752216311988
# Episode 300 complete (0.01s), loss: -0.174292501199, reward: -3, running reward: 1.04381845296
# Episode 400 complete (0.01s), loss: 0.0144229805627, reward: 1, running reward: 1.22407991594
# Episode 500 complete (0.01s), loss: 0.0263962776581, reward: 3, running reward: 1.30119917826
# Episode 600 complete (0.01s), loss: -0.0294951492271, reward: -3, running reward: 1.29326943624
# Episode 700 complete (0.01s), loss: 0.00346286575354, reward: 1, running reward: 1.31696050526
# Episode 800 complete (0.01s), loss: 0.0269631480658, reward: 3, running reward: 1.34912474219
# Episode 900 complete (0.01s), loss: -8.60150855393, reward: -1, running reward: 1.34474000697
# Episode 1000 complete (0.01s), loss: 0.00257819512973, reward: 1, running reward: 1.3483968714
# Episode 1100 complete (0.01s), loss: 0.0403537816387, reward: 3, running reward: 1.34684248717
# Episode 1200 complete (0.01s), loss: -0.01405740459, reward: -3, running reward: 1.29869825965
# Episode 1300 complete (0.01s), loss: 0.0235588528214, reward: 1, running reward: 1.36053981228
# Episode 1400 complete (0.01s), loss: 1.82370722248, reward: 1, running reward: 0.990496940151
# Episode 1500 complete (0.01s), loss: -9.40908047684, reward: -3, running reward: 0.675055509342
