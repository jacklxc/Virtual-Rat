# %%
import numpy as npp
import minpy.numpy as np
import cPickle
import matplotlib.pyplot as plt
import minpy
minpy.set_global_policy('only_numpy')

from SimplePolicyNetwork import SimplePolicyNetwork
from SimpleRLPolicyGradientSolver import SimpleRLPolicyGradientSolver
from simpleBox import simpleBox
from SimRat import SimRat
from dataProcessFunctions import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
weight_file = "good_weights/good_weights"
loaded_params = load_weights(weight_file+"4.pkl")

# %%
box = simpleBox(mode="alternative",length=1000,block_size=30,random_range=0,trial_per_episode=5, repeat = True)
val_X, val_y = box.X,box.y
rats = {}
for i in range(11):
    ratname = 'VirtualRat'+str(i)
    p2a_ratio = i*0.1
    print ratname, p2a_ratio
    model = SimplePolicyNetwork(hidden_dim=10,reg=0, noise_factor = 0)
    rat = SimRat(model)
    box = simpleBox(mode="switch_ratio",length=10000,block_size=30,random_range=0,
                    trial_per_episode=50, repeat = True, reward_ratio = 1, p2a = p2a_ratio, correction = False)
    solver = SimpleRLPolicyGradientSolver(model, box,
                                        update_rule='adam',
                                        optim_config={
                                            'learning_rate': 0.01,
                                            'decay_rate': 1
                                        },
                                        init_rule='xavier',
                                        num_episodes=601,
                                        verbose=False,
                                        supervised = True,
                                        print_every=100)
    #solver.load_params(loaded_params)
    solver.init()
    solver.train()

    
    probs = rat.predict(val_X,val_y)
    trial_window = 3
    np.set_printoptions(precision=2)
    plt.ylim([0,1])
    draw_3d(rat.p2a_prob, rat.a2p_prob, trial_window = 3)

    rats[ratname] = rat
    rat.addHistory(box.output_history())
    rat.computeLearningCurve()
    
trial_window = 3
p2a_mean, a2p_mean = meanPerformance(rats, trial_window = 3)
np.set_printoptions(precision=2)
plt.ylim([0,1])
draw_3d(p2a_mean, a2p_mean, trial_window = 3)
pro_mean, anti_mean = meanLearningCurve(rats)
learningCurve(pro_mean,anti_mean, rats)
# Out:
# VirtualRat0 0.0
# Episode 100 complete (0.14s), loss: 23268.4967243, reward: 4, running reward: -0.195346014245
# Episode 200 complete (0.15s), loss: 7075.59501338, reward: 44, running reward: 19.9806350305
# Episode 300 complete (0.15s), loss: 3078.93852521, reward: 46, running reward: 34.5737289838
# Episode 400 complete (0.15s), loss: 3449.3409255, reward: 48, running reward: 42.2099960578
# Episode 500 complete (0.15s), loss: 649.599967475, reward: 50, running reward: 46.0166246728
# Episode 600 complete (0.19s), loss: 1837.6523623, reward: 50, running reward: 47.8595870079
# VirtualRat1 0.1
# Episode 100 complete (0.15s), loss: 27989.5139765, reward: 4, running reward: 1.80652321948
# Episode 200 complete (0.42s), loss: 8822.18086198, reward: 36, running reward: 19.4859023445
# Episode 300 complete (0.18s), loss: 2181.92439038, reward: 44, running reward: 34.5736276557
# Episode 400 complete (0.15s), loss: 7306.72017712, reward: 48, running reward: 42.2040022085
# Episode 500 complete (0.26s), loss: 612.520144169, reward: 50, running reward: 46.10955616
# Episode 600 complete (0.16s), loss: 7213.0807737, reward: 48, running reward: 47.6190685723
# VirtualRat2 0.2
# Episode 100 complete (0.15s), loss: 22507.3080155, reward: 26, running reward: -9.44573037227
# Episode 200 complete (0.14s), loss: 9292.63583766, reward: 26, running reward: 14.3476673787
# Episode 300 complete (0.15s), loss: 3225.17280867, reward: 46, running reward: 31.7129622836
# Episode 400 complete (0.15s), loss: 2052.18732286, reward: 46, running reward: 40.8726695724
# Episode 500 complete (0.21s), loss: 956.174043935, reward: 46, running reward: 45.4079237515
# Episode 600 complete (0.18s), loss: 805.533259924, reward: 48, running reward: 47.5252096422
# VirtualRat3 0.3
# Episode 100 complete (0.14s), loss: 35666.0223868, reward: 8, running reward: 0.04370022992
# Episode 200 complete (0.15s), loss: 12301.3476838, reward: 40, running reward: 13.9456663035
# Episode 300 complete (0.15s), loss: 7850.9190964, reward: 40, running reward: 28.0287799086
# Episode 400 complete (0.15s), loss: 4988.71176039, reward: 36, running reward: 37.3257263935
# Episode 500 complete (0.15s), loss: 2526.15578467, reward: 48, running reward: 42.6106252916
# Episode 600 complete (0.15s), loss: 1557.58302381, reward: 48, running reward: 45.3928108246
# VirtualRat4 0.4
# Episode 100 complete (0.18s), loss: 37507.8887845, reward: 2, running reward: -8.04043169206
# Episode 200 complete (0.15s), loss: 26154.6088958, reward: 22, running reward: 1.67837209227
# Episode 300 complete (0.16s), loss: 6233.7227067, reward: 42, running reward: 21.5275235864
# Episode 400 complete (0.15s), loss: 3462.15154069, reward: 50, running reward: 35.337212462
# Episode 500 complete (0.16s), loss: 1554.5666057, reward: 48, running reward: 42.2203911087
# Episode 600 complete (0.16s), loss: 1432.23725244, reward: 50, running reward: 45.6477861152
# VirtualRat5 0.5
# Episode 100 complete (0.14s), loss: 27376.2947673, reward: 14, running reward: -4.47699242374
# Episode 200 complete (0.16s), loss: 19237.9496262, reward: 30, running reward: 10.0506144895
# Episode 300 complete (0.18s), loss: 6768.58620532, reward: 38, running reward: 25.9578924271
# Episode 400 complete (0.18s), loss: 8411.91517263, reward: 46, running reward: 36.7679402478
# Episode 500 complete (0.16s), loss: 2327.44015168, reward: 46, running reward: 42.5706019771
# Episode 600 complete (0.15s), loss: 7545.72596055, reward: 44, running reward: 45.8860859713
# VirtualRat6 0.6
# Episode 100 complete (0.14s), loss: 14385.5851752, reward: 26, running reward: -3.22740113191
# Episode 200 complete (0.15s), loss: 8265.11409526, reward: 42, running reward: 22.2419995639
# Episode 300 complete (0.16s), loss: 1383.36317302, reward: 48, running reward: 36.0231206441
# Episode 400 complete (0.15s), loss: 2577.05307742, reward: 48, running reward: 42.8773876743
# Episode 500 complete (0.16s), loss: 460.352478701, reward: 50, running reward: 46.0975268104
# Episode 600 complete (0.19s), loss: 1208.76465958, reward: 48, running reward: 47.6308390143
# VirtualRat7 0.7
# Episode 100 complete (0.14s), loss: 27474.6539026, reward: 4, running reward: 2.29939404322
# Episode 200 complete (0.15s), loss: 9260.86217789, reward: 34, running reward: 20.6749733697
# Episode 300 complete (0.16s), loss: 2267.64378168, reward: 48, running reward: 35.9445508038
# Episode 400 complete (0.15s), loss: 6345.05442426, reward: 44, running reward: 43.413188031
# Episode 500 complete (0.16s), loss: 657.968474251, reward: 48, running reward: 46.5747918853
# Episode 600 complete (0.16s), loss: 6620.46956635, reward: 46, running reward: 48.0229324389
# VirtualRat8 0.8
# Episode 100 complete (0.19s), loss: 38205.7796548, reward: 14, running reward: -21.6685468042
# Episode 200 complete (0.18s), loss: 38250.7219609, reward: 10, running reward: -6.23470760582
# Episode 300 complete (0.15s), loss: 29974.5896133, reward: 10, running reward: 2.4827546089
# Episode 400 complete (0.15s), loss: 22820.0550514, reward: 20, running reward: 9.65611892755
# Episode 500 complete (0.16s), loss: 15192.0126528, reward: 22, running reward: 18.6496015777
# Episode 600 complete (0.15s), loss: 17066.5882727, reward: 28, running reward: 28.8450098347
# VirtualRat9 0.9
# Episode 100 complete (0.15s), loss: 30983.6006156, reward: 0, running reward: -0.967093586185
# Episode 200 complete (0.15s), loss: 14593.2722634, reward: 28, running reward: 15.408693972
# Episode 300 complete (0.16s), loss: 3679.31933687, reward: 44, running reward: 31.1960388006
# Episode 400 complete (0.18s), loss: 8327.26077085, reward: 44, running reward: 40.3491944892
# Episode 500 complete (0.19s), loss: 949.975825382, reward: 48, running reward: 45.1351422441
# Episode 600 complete (0.16s), loss: 7195.98449762, reward: 42, running reward: 47.0608958598
# VirtualRat10 1.0
# Episode 100 complete (0.15s), loss: 21480.2739546, reward: 24, running reward: -5.5119153204
# Episode 200 complete (0.15s), loss: 5031.79653381, reward: 34, running reward: 20.6449789493
# Episode 300 complete (0.14s), loss: 3459.64353858, reward: 46, running reward: 35.8140796338
# Episode 400 complete (0.15s), loss: 2057.81207565, reward: 46, running reward: 42.724479052
# Episode 500 complete (0.15s), loss: 774.943081235, reward: 50, running reward: 46.1235367943
# Episode 600 complete (0.15s), loss: 1055.60660148, reward: 50, running reward: 47.9728592288
