# %% [markdown]
# # RNN's activation analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore, binned_statistic
from sklearn.linear_model import LinearRegression, SGDClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import cross_val_score
from ratEphysFunctions import *
import scipy.io as sio
from scipy.optimize import curve_fit

# %matplotlib inline
plt.rcParams['figure.figsize'] = (6.0, 4.5) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
np.random.seed(0)

# %%
fitted_table = sio.loadmat('mats/SGD_table_RNN_fitted.mat')['SGD_matrix']
# RNNid, time_step, score, pro, right, switch, hit_rate, same_score, 
# normalized_score, normalized_hit_rate, normalized_same_score, fit

# %%
plot_bins_RNN(fitted_table, bins=20, bins_fit=35,filename = "figures/RNNNormalizedRuleFitted.pdf")

# %%
encoding_score_parallel_plot(fitted_table,trial_type = "pro", time_step=None,minimum_trial = 4, filename = "figures/RNNproScore.pdf")
encoding_score_parallel_plot(fitted_table,trial_type = "anti", time_step=None,minimum_trial = 4, filename = "figures/RNNantiScore.pdf")

# %%
fitted_table = sio.loadmat('mats/SGD_table_RNN_target_fitted.mat')['SGD_matrix']
# RNNid, time_step, score, pro, right, switch, hit_rate, same_score, 
# normalized_score, normalized_hit_rate, normalized_same_score_target, fit_target

# %%
plot_bins_RNN(fitted_table, bins=20, bins_fit=35, target = True,filename = "figures/RNNNormalizedTargetFitted.pdf")

# %%
encoding_score_parallel_plot(fitted_table,trial_type = "left", time_step=None,minimum_trial = 4,filename = "figures/RNNleftScore.pdf")
encoding_score_parallel_plot(fitted_table,trial_type = "right", time_step=None,minimum_trial = 4,filename = "figures/RNNrightScore.pdf")
