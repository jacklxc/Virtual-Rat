# %%
import numpy as npp
import minpy.numpy as np
from minpy.nn import layers
from minpy.nn.model import ModelBase
from nn.solver import Solver
import matplotlib.pyplot as plt
import minpy
minpy.set_global_policy("only_numpy")
import cPickle
from VanillaRNN import vanillaRNN
from SimRat import SimRat
from trialGenerator import trialGenerator
from dataProcessFunctions import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
N=50
generator = trialGenerator(N)
block = 20

# %%
trainX,trainY = generator.getSequence(length = 10000, mode="alternative",p2a=0.5, block_size = block)
valX, valY = generator.getSequence(length = 5000, mode="alternative",p2a=0.5, block_size = block)
testX, testY = generator.getSequence(length = 5000, mode = "alternative", block_size = block, std=5)

# %%
weights = load_weights("good_weights/good_weights2.pkl")

# %%
learning_rate = 2e-3
RNN = vanillaRNN(N=N, hidden_dim=5, reg=0, p = 1, decay_rate = 1, noise_factor = 0)
solver = Solver(RNN,
                trainX, trainY,
                valX, valY,
                num_epochs=30,
                batch_length = 5,
                init_rule='xavier',
                update_rule='adam',
                optim_config={
                      'learning_rate': learning_rate,
                    },
                lr_decay = 1,
                verbose=True,
               )
solver.init()
#solver.load_params(weights)

trial_window = 3
rat = SimRat(RNN,trial_window=trial_window)
probs = rat.predict(testX,testY)
heatmap(rat.RNN.h.asnumpy(),start=0,end=300)
ratname = 'SimRat' 
sample_probabilities(probs, ratname, start=0,end = 50) 
#sample_correct_rate(rat, start=0, end = 1000)
sample_correct_rate_new(rat, start=0, end = 1000) 
p2a, a2p = rat.p2a_prob, rat.a2p_prob
p2a_left, a2p_left = rat.p2a_left_prob, rat.a2p_left_prob
p2a_right, a2p_right = rat.p2a_right_prob, rat.a2p_right_prob

#draw_3d(p2a, a2p, trial_window = trial_window)
draw_3d_new(p2a_left, p2a_right, a2p_left, a2p_right, trial_window = trial_window)
parallel_coordinate(rat.RNN.h.asnumpy(), start = 0, end = 1000)

parameters = []
for i in range(3):
    solver.change_settings(learning_rate=learning_rate/2)
    solver.train()
    
    trial_window = 3
    rat = SimRat(RNN,trial_window=trial_window)
    probs = rat.predict(testX,testY)
    heatmap(rat.RNN.h.asnumpy(),start=0,end=300)
    ratname = 'SimRat'
    loss_history(solver, ratname) 
    sample_probabilities(probs, ratname, start=0,end = 50) 
    #sample_correct_rate(rat, start=0, end = 1000)
    sample_correct_rate_new(rat, start=0, end = 1000) 
    p2a, a2p = rat.p2a_prob, rat.a2p_prob
    p2a_left, a2p_left = rat.p2a_left_prob, rat.a2p_left_prob
    p2a_right, a2p_right = rat.p2a_right_prob, rat.a2p_right_prob

    #draw_3d(p2a, a2p, trial_window = trial_window)
    draw_3d_new(p2a_left, p2a_right, a2p_left, a2p_right, trial_window = trial_window)

    parallel_coordinate(rat.RNN.h.asnumpy(), start = 0, end = 1000)
    #phasePlane(rat.RNN.h.asnumpy(),dim1=0,dim2=1,start=0,end=1000)
# Out:
# (Iteration 1 / 1200) loss: 10.999169
# (Epoch 1 / 30) train acc: 0.3842, val_acc: 0.3752, time: 0.967967033386.
# (Iteration 41 / 1200) loss: 8.803987
# (Epoch 2 / 30) train acc: 0.5024, val_acc: 0.4954, time: 1.05613899231.
# (Iteration 81 / 1200) loss: 7.425589
# (Epoch 3 / 30) train acc: 0.5135, val_acc: 0.5058, time: 0.990781784058.
# (Iteration 121 / 1200) loss: 6.547290
# (Epoch 4 / 30) train acc: 0.5466, val_acc: 0.5416, time: 1.20013785362.
# (Iteration 161 / 1200) loss: 5.904706
# (Epoch 5 / 30) train acc: 0.5593, val_acc: 0.5544, time: 0.981101036072.
# (Iteration 201 / 1200) loss: 5.385402
# (Epoch 6 / 30) train acc: 0.5605, val_acc: 0.5562, time: 0.907665967941.
# (Iteration 241 / 1200) loss: 4.950137
# (Epoch 7 / 30) train acc: 0.565, val_acc: 0.5614, time: 1.11812520027.
# (Iteration 281 / 1200) loss: 4.577269
# (Epoch 8 / 30) train acc: 0.5843, val_acc: 0.5816, time: 0.97439789772.
# (Iteration 321 / 1200) loss: 4.258459
# (Epoch 9 / 30) train acc: 0.6186, val_acc: 0.6212, time: 1.19228196144.
# (Iteration 361 / 1200) loss: 3.986633
# (Epoch 10 / 30) train acc: 0.6542, val_acc: 0.6626, time: 1.1090221405.
# (Iteration 401 / 1200) loss: 3.753397
# (Epoch 11 / 30) train acc: 0.6441, val_acc: 0.652, time: 0.983859062195.
# (Iteration 441 / 1200) loss: 3.547625
# (Epoch 12 / 30) train acc: 0.6546, val_acc: 0.6608, time: 0.749727964401.
# (Iteration 481 / 1200) loss: 3.356321
# (Epoch 13 / 30) train acc: 0.6817, val_acc: 0.6908, time: 0.814209938049.
# (Iteration 521 / 1200) loss: 3.168431
# (Epoch 14 / 30) train acc: 0.7192, val_acc: 0.726, time: 0.757176876068.
# (Iteration 561 / 1200) loss: 2.979008
# (Epoch 15 / 30) train acc: 0.7376, val_acc: 0.744, time: 0.769196987152.
# (Iteration 601 / 1200) loss: 2.789866
# (Epoch 16 / 30) train acc: 0.8053, val_acc: 0.8086, time: 0.72043299675.
# (Iteration 641 / 1200) loss: 2.605191
# (Epoch 17 / 30) train acc: 0.824, val_acc: 0.8298, time: 0.736132860184.
# (Iteration 681 / 1200) loss: 2.427186
# (Epoch 18 / 30) train acc: 0.8958, val_acc: 0.8948, time: 0.709102153778.
# (Iteration 721 / 1200) loss: 2.255785
# (Epoch 19 / 30) train acc: 0.9411, val_acc: 0.9434, time: 0.758733987808.
# (Iteration 761 / 1200) loss: 2.090168
# (Epoch 20 / 30) train acc: 0.9948, val_acc: 0.9936, time: 0.730466842651.
# (Iteration 801 / 1200) loss: 1.929595
# (Epoch 21 / 30) train acc: 0.9948, val_acc: 0.9936, time: 0.727589130402.
# (Iteration 841 / 1200) loss: 1.773694
# (Epoch 22 / 30) train acc: 1.0, val_acc: 1.0, time: 0.795892000198.
# (Iteration 881 / 1200) loss: 1.622733
# (Epoch 23 / 30) train acc: 1.0, val_acc: 1.0, time: 0.744832992554.
# (Iteration 921 / 1200) loss: 1.477719
# (Epoch 24 / 30) train acc: 1.0, val_acc: 1.0, time: 0.715713024139.
# (Iteration 961 / 1200) loss: 1.340161
# (Epoch 25 / 30) train acc: 1.0, val_acc: 1.0, time: 0.712785959244.
# (Iteration 1001 / 1200) loss: 1.211638
# (Epoch 26 / 30) train acc: 1.0, val_acc: 1.0, time: 0.716349124908.
# (Iteration 1041 / 1200) loss: 1.093409
# (Epoch 27 / 30) train acc: 1.0, val_acc: 1.0, time: 0.764405965805.
# (Iteration 1081 / 1200) loss: 0.986175
# (Epoch 28 / 30) train acc: 1.0, val_acc: 1.0, time: 0.720884084702.
# (Iteration 1121 / 1200) loss: 0.890021
# (Epoch 29 / 30) train acc: 1.0, val_acc: 1.0, time: 0.73491692543.
# (Iteration 1161 / 1200) loss: 0.804502
# (Epoch 30 / 30) train acc: 1.0, val_acc: 1.0, time: 0.751194000244.
# (Iteration 1 / 1200) loss: 1.622733
# (Epoch 1 / 30) train acc: 1.0, val_acc: 1.0, time: 0.944725990295.
# (Iteration 41 / 1200) loss: 1.467341
# (Epoch 2 / 30) train acc: 1.0, val_acc: 1.0, time: 0.708716869354.
# (Iteration 81 / 1200) loss: 1.309336
# (Epoch 3 / 30) train acc: 1.0, val_acc: 1.0, time: 0.723161935806.
# (Iteration 121 / 1200) loss: 1.164818
# (Epoch 4 / 30) train acc: 1.0, val_acc: 1.0, time: 0.737008094788.
# (Iteration 161 / 1200) loss: 1.035372
# (Epoch 5 / 30) train acc: 1.0, val_acc: 1.0, time: 0.729413032532.
# (Iteration 201 / 1200) loss: 0.921255
# (Epoch 6 / 30) train acc: 1.0, val_acc: 1.0, time: 0.717470884323.
# (Iteration 241 / 1200) loss: 0.821738
# (Epoch 7 / 30) train acc: 1.0, val_acc: 1.0, time: 0.761132955551.
# (Iteration 281 / 1200) loss: 0.735472
# (Epoch 8 / 30) train acc: 1.0, val_acc: 1.0, time: 0.707587003708.
# (Iteration 321 / 1200) loss: 0.660849
# (Epoch 9 / 30) train acc: 1.0, val_acc: 1.0, time: 0.725149154663.
# (Iteration 361 / 1200) loss: 0.596263
# (Epoch 10 / 30) train acc: 1.0, val_acc: 1.0, time: 0.755954027176.
# (Iteration 401 / 1200) loss: 0.540238
# (Epoch 11 / 30) train acc: 1.0, val_acc: 1.0, time: 0.782279968262.
# (Iteration 441 / 1200) loss: 0.491483
# (Epoch 12 / 30) train acc: 1.0, val_acc: 1.0, time: 0.711817979813.
# (Iteration 481 / 1200) loss: 0.448894
# (Epoch 13 / 30) train acc: 1.0, val_acc: 1.0, time: 0.75787115097.
# (Iteration 521 / 1200) loss: 0.411536
# (Epoch 14 / 30) train acc: 1.0, val_acc: 1.0, time: 0.720884084702.
# (Iteration 561 / 1200) loss: 0.378625
# (Epoch 15 / 30) train acc: 1.0, val_acc: 1.0, time: 0.982802867889.
# (Iteration 601 / 1200) loss: 0.349504
# (Epoch 16 / 30) train acc: 1.0, val_acc: 1.0, time: 0.958703994751.
# (Iteration 641 / 1200) loss: 0.323626
# (Epoch 17 / 30) train acc: 1.0, val_acc: 1.0, time: 0.749711036682.
# (Iteration 681 / 1200) loss: 0.300533
# (Epoch 18 / 30) train acc: 1.0, val_acc: 1.0, time: 0.716804981232.
# (Iteration 721 / 1200) loss: 0.279841
# (Epoch 19 / 30) train acc: 1.0, val_acc: 1.0, time: 0.742626190186.
# (Iteration 761 / 1200) loss: 0.261227
# (Epoch 20 / 30) train acc: 1.0, val_acc: 1.0, time: 0.713561058044.
# (Iteration 801 / 1200) loss: 0.244423
# (Epoch 21 / 30) train acc: 1.0, val_acc: 1.0, time: 0.757042169571.
# (Iteration 841 / 1200) loss: 0.229198
# (Epoch 22 / 30) train acc: 1.0, val_acc: 1.0, time: 0.754945039749.
# (Iteration 881 / 1200) loss: 0.215358
# (Epoch 23 / 30) train acc: 1.0, val_acc: 1.0, time: 0.729262828827.
# (Iteration 921 / 1200) loss: 0.202738
# (Epoch 24 / 30) train acc: 1.0, val_acc: 1.0, time: 0.794306993484.
# (Iteration 961 / 1200) loss: 0.191197
# (Epoch 25 / 30) train acc: 1.0, val_acc: 1.0, time: 0.743055105209.
# (Iteration 1001 / 1200) loss: 0.180612
# (Epoch 26 / 30) train acc: 1.0, val_acc: 1.0, time: 0.737960100174.
# (Iteration 1041 / 1200) loss: 0.170879
# (Epoch 27 / 30) train acc: 1.0, val_acc: 1.0, time: 0.713194131851.
# (Iteration 1081 / 1200) loss: 0.161907
# (Epoch 28 / 30) train acc: 1.0, val_acc: 1.0, time: 0.760023117065.
# (Iteration 1121 / 1200) loss: 0.153617
# (Epoch 29 / 30) train acc: 1.0, val_acc: 1.0, time: 0.700943946838.
# (Iteration 1161 / 1200) loss: 0.145939
# (Epoch 30 / 30) train acc: 1.0, val_acc: 1.0, time: 0.723849058151.
# (Iteration 1 / 1200) loss: 0.138815
# (Epoch 1 / 30) train acc: 1.0, val_acc: 1.0, time: 1.1105761528.
# (Iteration 41 / 1200) loss: 0.132190
# (Epoch 2 / 30) train acc: 1.0, val_acc: 1.0, time: 0.851433038712.
# (Iteration 81 / 1200) loss: 0.126017
# (Epoch 3 / 30) train acc: 1.0, val_acc: 1.0, time: 0.904928922653.
# (Iteration 121 / 1200) loss: 0.120257
# (Epoch 4 / 30) train acc: 1.0, val_acc: 1.0, time: 0.915330886841.
# (Iteration 161 / 1200) loss: 0.114871
# (Epoch 5 / 30) train acc: 1.0, val_acc: 1.0, time: 0.983880996704.
# (Iteration 201 / 1200) loss: 0.109827
# (Epoch 6 / 30) train acc: 1.0, val_acc: 1.0, time: 1.0370349884.
# (Iteration 241 / 1200) loss: 0.105096
# (Epoch 7 / 30) train acc: 1.0, val_acc: 1.0, time: 0.949923038483.
# (Iteration 281 / 1200) loss: 0.100653
# (Epoch 8 / 30) train acc: 1.0, val_acc: 1.0, time: 1.12940502167.
# (Iteration 321 / 1200) loss: 0.096474
# (Epoch 9 / 30) train acc: 1.0, val_acc: 1.0, time: 0.99587392807.
# (Iteration 361 / 1200) loss: 0.092537
# (Epoch 10 / 30) train acc: 1.0, val_acc: 1.0, time: 1.42253112793.
# (Iteration 401 / 1200) loss: 0.088824
# (Epoch 11 / 30) train acc: 1.0, val_acc: 1.0, time: 0.844118833542.
# (Iteration 441 / 1200) loss: 0.085319
# (Epoch 12 / 30) train acc: 1.0, val_acc: 1.0, time: 0.725009918213.
# (Iteration 481 / 1200) loss: 0.082005
# (Epoch 13 / 30) train acc: 1.0, val_acc: 1.0, time: 0.806460142136.
# (Iteration 521 / 1200) loss: 0.078868
# (Epoch 14 / 30) train acc: 1.0, val_acc: 1.0, time: 0.751046895981.
# (Iteration 561 / 1200) loss: 0.075897
# (Epoch 15 / 30) train acc: 1.0, val_acc: 1.0, time: 1.02927184105.
# (Iteration 601 / 1200) loss: 0.073079
# (Epoch 16 / 30) train acc: 1.0, val_acc: 1.0, time: 0.883618116379.
# (Iteration 641 / 1200) loss: 0.070404
# (Epoch 17 / 30) train acc: 1.0, val_acc: 1.0, time: 0.807330846786.
# (Iteration 681 / 1200) loss: 0.067861
# (Epoch 18 / 30) train acc: 1.0, val_acc: 1.0, time: 0.855993032455.
# (Iteration 721 / 1200) loss: 0.065444
# (Epoch 19 / 30) train acc: 1.0, val_acc: 1.0, time: 0.811928987503.
# (Iteration 761 / 1200) loss: 0.063142
# (Epoch 20 / 30) train acc: 1.0, val_acc: 1.0, time: 0.825999975204.
# (Iteration 801 / 1200) loss: 0.060949
# (Epoch 21 / 30) train acc: 1.0, val_acc: 1.0, time: 0.814753055573.
# (Iteration 841 / 1200) loss: 0.058859
# (Epoch 22 / 30) train acc: 1.0, val_acc: 1.0, time: 0.768713951111.
# (Iteration 881 / 1200) loss: 0.056864
# (Epoch 23 / 30) train acc: 1.0, val_acc: 1.0, time: 0.72713303566.
# (Iteration 921 / 1200) loss: 0.054959
# (Epoch 24 / 30) train acc: 1.0, val_acc: 1.0, time: 0.841194868088.
# (Iteration 961 / 1200) loss: 0.053139
# (Epoch 25 / 30) train acc: 1.0, val_acc: 1.0, time: 0.828545093536.
# (Iteration 1001 / 1200) loss: 0.051398
# (Epoch 26 / 30) train acc: 1.0, val_acc: 1.0, time: 0.750748872757.
# (Iteration 1041 / 1200) loss: 0.049732
# (Epoch 27 / 30) train acc: 1.0, val_acc: 1.0, time: 0.767213106155.
# (Iteration 1081 / 1200) loss: 0.048137
# (Epoch 28 / 30) train acc: 1.0, val_acc: 1.0, time: 1.11927390099.
# (Iteration 1121 / 1200) loss: 0.046609
# (Epoch 29 / 30) train acc: 1.0, val_acc: 1.0, time: 0.774571895599.
# (Iteration 1161 / 1200) loss: 0.045145
# (Epoch 30 / 30) train acc: 1.0, val_acc: 1.0, time: 0.813435077667.

# %%
trial_window = 3
rat = SimRat(RNN,trial_window=trial_window)
probs = rat.predict(testX,testY)
heatmap(rat.RNN.h.asnumpy(),start=0,end=300)
ratname = 'SimRat' 
sample_probabilities(probs, ratname, start=0,end = 50) 
#sample_correct_rate(rat, start=0, end = 1000)
sample_correct_rate_new(rat, start=0, end = 1000) 

p2a, a2p = rat.p2a_prob, rat.a2p_prob
p2a_left, a2p_left = rat.p2a_left_prob, rat.a2p_left_prob
p2a_right, a2p_right = rat.p2a_right_prob, rat.a2p_right_prob

#draw_3d(p2a, a2p, trial_window = trial_window)
draw_3d_new(p2a_left, p2a_right, a2p_left, a2p_right, trial_window = trial_window)
#phasePlane(rat.RNN.h.asnumpy(),dim1=0,dim2=1,start=0,end=5000, trajectory = False, 
#           scatter = False, mean=True, ylim = (-1.5,1.5), xlim=(-1.5,1.5))
parallel_coordinate(rat.RNN.h.asnumpy(), start = 0, end = 1000)

# %%
for k, v in RNN.params.iteritems():
    print k,v
# Out:
# Wh [[ 0.60862965  0.20413854 -0.62242292  1.67179209 -0.12063928]
#  [-0.73749247  0.15835197  0.40636071 -0.17439903 -0.36324042]
#  [-0.09527821  0.65165216  0.026308    0.23149154 -0.48307368]
#  [-0.43388602 -0.79000021 -0.61656669  0.28498212 -1.4933535 ]
#  [ 0.19384657  0.25053114 -1.65872538  1.23374559  0.92119525]]
# b [-0.99923159 -0.73408561  2.3858508   2.68214941 -1.36349233]
# ba [-0.88126367  3.08457044 -1.11138266]
# Wa [[ 3.06199861 -2.93831821 -0.39376922]
#  [ 0.39378262 -2.61875859  0.79925473]
#  [ 2.35359701 -3.11292429 -1.20178606]
#  [-0.13197375 -0.98364119 -0.51804955]
#  [-0.33386995 -0.39564782  1.79537632]]
# Wx [[ 3.14909604 -2.60702164 -1.19149969 -0.30739147 -1.43463351]
#  [ 2.64494993  1.63748458 -2.30544507  1.02594622 -1.96342727]
#  [-0.62551887 -0.57275214  0.35401437  1.1488284  -0.65946055]]
